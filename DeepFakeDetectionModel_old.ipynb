# %% [markdown]
# <a href="https://colab.research.google.com/github/avilaJorge/CSE253_FinalProject/blob/master/DeepFakeDetectionModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %run DeepFake_Dataloader.py
# %run utils.py

# %%
# imports pytorch
import torch
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# Numpy, Matplotlib, and PIL
import numpy as np
import matplotlib.pyplot as plt

# general imports
import pprint

# My imports
from DeepFake_Dataloader import get_dataloaders
from models import LinearRegression, save_model
from utils import RunningAverage

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
trn_dl, val_dl, tst_dl = get_dataloaders()

# %%
# img2 = Image.open('./Frequency/Faces-HQ/celebA-HQ_10K/0.jpg')
# # display(img2)
# img2 = img2.convert('L')

# mag_spectrum = np_magnitude_spectrum(img2)
# rad2 = np_radial_profile(mag_spectrum, center=(mag_spectrum.shape[0]/2, mag_spectrum.shape[1]/2))
# plt.plot(rad2)
# plt.show()

# rad_p, t = next(iter(trn_dl))
# rad_p = rad_p.squeeze(0)
# # t_img = torch.from_numpy(np.asarray(img2)).squeeze(0).float()
# # ms = magnitude_spectrum(t_img)
# # rad2 = radial_profile(ms, center=(ms.shape[0]/2, ms.shape[1]/2))
# plt.plot(rad_p.cpu())
# plt.show()

# %%
s_epoch      = 1
num_epochs   = 100
log_step     = 10e5
lr_rate      = 1e-3
best_loss    = float('inf')
prev_loss    = float('inf')
loss_inc_cnt = 0
stop_early   = False
load_model   = False
model_name   = 'LogisticRegressionModel'

lr_model = LinearRegression(725, 1500, 100).to(device)
criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(lr_model.parameters(), lr=lr_rate)

if load_model:
    lr_model.load_state_dict(torch.load(''))

# %%
def train(model, dataloader, validation_loader):
    
    # Train the models
    total_step = len(dataloader)
    for epoch in range(s_epoch, num_epochs):
        ts = time.time()
        print_info("----- Starting Training Epoch lr=%.8f best_loss=%f ------\n" 
                   % (lr_rate, best_loss))
        for i, (x, y) in enumerate(dataloader):
            optimizer.zero_grad()

            # Move to GPU
            x = x.to(device)
            y = y.to(device)

            # Forward, backward and optimize
            pred = model(x)
            loss = criterion(pred, y)
            loss.backward()
            optimizer.step()
            loss=loss.item()
            
            # Print log info
            if i % log_step == 0:
                print_info('"Epoch": [{}/{}], "Step": [{}/{}], "Loss": {:.4f} \n'
                      .format(epoch, num_epochs, i, total_step, loss))
                
        print_info("Finished Training. Time elapsed %f \n" % (time.time() - ts))

        loss = evaluate(model, epoch, dataloader, validation=False)
        print_info('"Training Epoch Done": "Epoch": [{}/{}], "Loss": {:.4f} \n'
                      .format(epoch, num_epochs, loss)) 
        
        loss = evaluate(model, epoch, validation_loader) 
        print_info('"Validation Epoch Done": "Epoch": [{}/{}], "Loss": {:.4f} \n'
                      .format(epoch, num_epochs, loss))

def evaluate(model, epoch, data_loader, validation=True):

    global best_loss
    global prev_loss
    global loss_inc_cnt
    global stop_early
    
    with torch.no_grad():
        losses = RunningAverage()
        ts = time.time()
        print_info("----- Starting Evaluation ------\n")
        total_step = len(data_loader)
        
        for i, (x, y) in enumerate(data_loader):

            # Move to GPU
            x = x.to(device)
            y = y.to(device)

            # Evaluate
            pred = model(x)
            losses.update(criterion(pred, y).item())

        print_info("Finished evaluation. Time elapsed %f \n" % (time.time() - ts))
        loss = losses.value

        if validation:
            if best_loss > loss:
                best_loss = loss
                print_info('"Best Loss": ' + str(best_loss) + '\n')
                save_model(model, 'Best-' + model_name, dt, path)

            loss_inc_cnt = loss_inc_cnt + 1 if prev_loss < loss else 0
            if loss_inc_cnt > 2: stop_early = True
            save_model(model, model_name, dt, path)
            print_info("Validation Loss has gone up %d times.\n" % (loss_inc_cnt))
            prev_loss = loss
        
        return loss

# %%
train(lr_model, trn_dl, val_dl)
# Out:
# ----- Starting Training Epoch lr=0.00100000 best_loss=inf ------
#
# "Epoch": [1/100], "Step": [0/188], "Loss": 0.6944
#
# Finished Training. Time elapsed 1.674551
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.873926
#
# "Training Epoch Done": "Epoch": [1/100], "Loss": 0.6886
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.455712
#
# "Best Loss": 0.6889824678027441
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [1/100], "Loss": 0.6890
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.688982 ------
#
# "Epoch": [2/100], "Step": [0/188], "Loss": 0.6869
#
# Finished Training. Time elapsed 1.064298
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.900088
#
# "Training Epoch Done": "Epoch": [2/100], "Loss": 0.6849
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.457886
#
# "Best Loss": 0.6846829387876723
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [2/100], "Loss": 0.6847
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.684683 ------
#
# "Epoch": [3/100], "Step": [0/188], "Loss": 0.6857
#
# Finished Training. Time elapsed 1.072166
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.887192
#
# "Training Epoch Done": "Epoch": [3/100], "Loss": 0.6792
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.452281
#
# "Best Loss": 0.6792154520276994
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [3/100], "Loss": 0.6792
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.679215 ------
#
# "Epoch": [4/100], "Step": [0/188], "Loss": 0.6800
#
# Finished Training. Time elapsed 1.044633
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.883265
#
# "Training Epoch Done": "Epoch": [4/100], "Loss": 0.6708
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.450159
#
# "Best Loss": 0.6713612230997237
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [4/100], "Loss": 0.6714
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.671361 ------
#
# "Epoch": [5/100], "Step": [0/188], "Loss": 0.6728
#
# Finished Training. Time elapsed 1.051087
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.887196
#
# "Training Epoch Done": "Epoch": [5/100], "Loss": 0.6575
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460261
#
# "Best Loss": 0.6576721970997159
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [5/100], "Loss": 0.6577
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.657672 ------
#
# "Epoch": [6/100], "Step": [0/188], "Loss": 0.6571
#
# Finished Training. Time elapsed 1.070791
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.889342
#
# "Training Epoch Done": "Epoch": [6/100], "Loss": 0.6484
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.451642
#
# "Best Loss": 0.6483009258906046
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [6/100], "Loss": 0.6483
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.648301 ------
#
# "Epoch": [7/100], "Step": [0/188], "Loss": 0.6476
#
# Finished Training. Time elapsed 1.056522
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.894309
#
# "Training Epoch Done": "Epoch": [7/100], "Loss": 0.6449
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.458455
#
# "Best Loss": 0.6453439829841493
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [7/100], "Loss": 0.6453
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.645344 ------
#
# "Epoch": [8/100], "Step": [0/188], "Loss": 0.6443
#
# Finished Training. Time elapsed 1.046701
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.887887
#
# "Training Epoch Done": "Epoch": [8/100], "Loss": 0.6236
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.456460
#
# "Best Loss": 0.6240663821735081
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [8/100], "Loss": 0.6241
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.624066 ------
#
# "Epoch": [9/100], "Step": [0/188], "Loss": 0.6209
#
# Finished Training. Time elapsed 1.037979
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.892215
#
# "Training Epoch Done": "Epoch": [9/100], "Loss": 0.6262
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460580
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [9/100], "Loss": 0.6267
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.624066 ------
#
# "Epoch": [10/100], "Step": [0/188], "Loss": 0.6291
#
# Finished Training. Time elapsed 1.063738
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.896807
#
# "Training Epoch Done": "Epoch": [10/100], "Loss": 0.6006
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.462317
#
# "Best Loss": 0.6009933834984189
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [10/100], "Loss": 0.6010
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.600993 ------
#
# "Epoch": [11/100], "Step": [0/188], "Loss": 0.6027
#
# Finished Training. Time elapsed 1.049568
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.891519
#
# "Training Epoch Done": "Epoch": [11/100], "Loss": 0.5906
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.454280
#
# "Best Loss": 0.5908950453712827
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [11/100], "Loss": 0.5909
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.590895 ------
#
# "Epoch": [12/100], "Step": [0/188], "Loss": 0.5893
#
# Finished Training. Time elapsed 1.053050
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.888837
#
# "Training Epoch Done": "Epoch": [12/100], "Loss": 0.6053
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.459476
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [12/100], "Loss": 0.6053
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.590895 ------
#
# "Epoch": [13/100], "Step": [0/188], "Loss": 0.6123
#
# Finished Training. Time elapsed 1.054698
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.892060
#
# "Training Epoch Done": "Epoch": [13/100], "Loss": 0.5863
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460639
#
# "Best Loss": 0.5879708878577702
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [13/100], "Loss": 0.5880
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.587971 ------
#
# "Epoch": [14/100], "Step": [0/188], "Loss": 0.5834
#
# Finished Training. Time elapsed 1.057160
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.894042
#
# "Training Epoch Done": "Epoch": [14/100], "Loss": 0.5545
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.456839
#
# "Best Loss": 0.554887465068272
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [14/100], "Loss": 0.5549
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.554887 ------
#
# "Epoch": [15/100], "Step": [0/188], "Loss": 0.5635
#
# Finished Training. Time elapsed 1.052663
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.898440
#
# "Training Epoch Done": "Epoch": [15/100], "Loss": 0.5547
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.447600
#
# "Best Loss": 0.5546997899100894
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [15/100], "Loss": 0.5547
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.554700 ------
#
# "Epoch": [16/100], "Step": [0/188], "Loss": 0.5588
#
# Finished Training. Time elapsed 1.070158
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.891933
#
# "Training Epoch Done": "Epoch": [16/100], "Loss": 0.5350
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.449798
#
# "Best Loss": 0.5355450359601825
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [16/100], "Loss": 0.5355
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.535545 ------
#
# "Epoch": [17/100], "Step": [0/188], "Loss": 0.5366
#
# Finished Training. Time elapsed 1.039031
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.903257
#
# "Training Epoch Done": "Epoch": [17/100], "Loss": 0.5291
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.463825
#
# "Best Loss": 0.5305456907030138
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [17/100], "Loss": 0.5305
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.530546 ------
#
# "Epoch": [18/100], "Step": [0/188], "Loss": 0.5246
#
# Finished Training. Time elapsed 1.055200
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.900731
#
# "Training Epoch Done": "Epoch": [18/100], "Loss": 0.5108
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.448411
#
# "Best Loss": 0.5115545004133194
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [18/100], "Loss": 0.5116
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.511555 ------
#
# "Epoch": [19/100], "Step": [0/188], "Loss": 0.5105
#
# Finished Training. Time elapsed 1.043070
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.888667
#
# "Training Epoch Done": "Epoch": [19/100], "Loss": 0.4980
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.451466
#
# "Best Loss": 0.49857585534216864
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [19/100], "Loss": 0.4986
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.498576 ------
#
# "Epoch": [20/100], "Step": [0/188], "Loss": 0.4849
#
# Finished Training. Time elapsed 1.079218
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.898248
#
# "Training Epoch Done": "Epoch": [20/100], "Loss": 0.4849
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.456128
#
# "Best Loss": 0.4852136520166246
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [20/100], "Loss": 0.4852
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.485214 ------
#
# "Epoch": [21/100], "Step": [0/188], "Loss": 0.4893
#
# Finished Training. Time elapsed 1.063622
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.894471
#
# "Training Epoch Done": "Epoch": [21/100], "Loss": 0.5074
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.452712
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [21/100], "Loss": 0.5092
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.485214 ------
#
# "Epoch": [22/100], "Step": [0/188], "Loss": 0.5100
#
# Finished Training. Time elapsed 1.052733
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.886052
#
# "Training Epoch Done": "Epoch": [22/100], "Loss": 0.4644
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.463892
#
# "Best Loss": 0.4651877766563779
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [22/100], "Loss": 0.4652
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.465188 ------
#
# "Epoch": [23/100], "Step": [0/188], "Loss": 0.4707
#
# Finished Training. Time elapsed 1.047622
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.897920
#
# "Training Epoch Done": "Epoch": [23/100], "Loss": 0.4537
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.450649
#
# "Best Loss": 0.4545318191013639
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [23/100], "Loss": 0.4545
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.454532 ------
#
# "Epoch": [24/100], "Step": [0/188], "Loss": 0.4606
#
# Finished Training. Time elapsed 1.059630
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.889697
#
# "Training Epoch Done": "Epoch": [24/100], "Loss": 0.4616
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460883
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [24/100], "Loss": 0.4637
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.454532 ------
#
# "Epoch": [25/100], "Step": [0/188], "Loss": 0.4561
#
# Finished Training. Time elapsed 1.056091
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.890837
#
# "Training Epoch Done": "Epoch": [25/100], "Loss": 0.4418
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.465245
#
# "Best Loss": 0.4426835070526789
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [25/100], "Loss": 0.4427
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.442684 ------
#
# "Epoch": [26/100], "Step": [0/188], "Loss": 0.4528
#
# Finished Training. Time elapsed 1.052289
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.890555
#
# "Training Epoch Done": "Epoch": [26/100], "Loss": 0.4706
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.457485
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [26/100], "Loss": 0.4729
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.442684 ------
#
# "Epoch": [27/100], "Step": [0/188], "Loss": 0.4729
#
# Finished Training. Time elapsed 1.050181
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.891769
#
# "Training Epoch Done": "Epoch": [27/100], "Loss": 0.4505
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.462644
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [27/100], "Loss": 0.4517
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.442684 ------
#
# "Epoch": [28/100], "Step": [0/188], "Loss": 0.4542
#
# Finished Training. Time elapsed 1.044832
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.896616
#
# "Training Epoch Done": "Epoch": [28/100], "Loss": 0.5036
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.454566
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [28/100], "Loss": 0.5047
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.442684 ------
#
# "Epoch": [29/100], "Step": [0/188], "Loss": 0.5048
#
# Finished Training. Time elapsed 1.043770
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.895462
#
# "Training Epoch Done": "Epoch": [29/100], "Loss": 0.4279
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.461277
#
# "Best Loss": 0.42878555683862596
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [29/100], "Loss": 0.4288
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.428786 ------
#
# "Epoch": [30/100], "Step": [0/188], "Loss": 0.4121
#
# Finished Training. Time elapsed 1.050152
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.893998
#
# "Training Epoch Done": "Epoch": [30/100], "Loss": 0.4296
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.462544
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [30/100], "Loss": 0.4302
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.428786 ------
#
# "Epoch": [31/100], "Step": [0/188], "Loss": 0.4389
#
# Finished Training. Time elapsed 1.055758
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.890218
#
# "Training Epoch Done": "Epoch": [31/100], "Loss": 0.4132
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.455151
#
# "Best Loss": 0.41393639454765924
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [31/100], "Loss": 0.4139
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.413936 ------
#
# "Epoch": [32/100], "Step": [0/188], "Loss": 0.4093
#
# Finished Training. Time elapsed 1.048225
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.877151
#
# "Training Epoch Done": "Epoch": [32/100], "Loss": 0.4117
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.447803
#
# "Best Loss": 0.4124797052807278
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [32/100], "Loss": 0.4125
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.412480 ------
#
# "Epoch": [33/100], "Step": [0/188], "Loss": 0.4077
#
# Finished Training. Time elapsed 1.054250
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.881149
#
# "Training Epoch Done": "Epoch": [33/100], "Loss": 0.4234
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.453865
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [33/100], "Loss": 0.4240
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.412480 ------
#
# "Epoch": [34/100], "Step": [0/188], "Loss": 0.4215
#
# Finished Training. Time elapsed 1.063203
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.886491
#
# "Training Epoch Done": "Epoch": [34/100], "Loss": 0.3868
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460738
#
# "Best Loss": 0.3877493176195357
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [34/100], "Loss": 0.3877
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [35/100], "Step": [0/188], "Loss": 0.3883
#
# Finished Training. Time elapsed 1.065645
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.893337
#
# "Training Epoch Done": "Epoch": [35/100], "Loss": 0.5244
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.446468
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [35/100], "Loss": 0.5249
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [36/100], "Step": [0/188], "Loss": 0.5289
#
# Finished Training. Time elapsed 1.051372
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.903137
#
# "Training Epoch Done": "Epoch": [36/100], "Loss": 0.4410
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.458596
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [36/100], "Loss": 0.4418
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [37/100], "Step": [0/188], "Loss": 0.4565
#
# Finished Training. Time elapsed 1.047717
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.895205
#
# "Training Epoch Done": "Epoch": [37/100], "Loss": 0.4526
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.454622
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [37/100], "Loss": 0.4538
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [38/100], "Step": [0/188], "Loss": 0.4383
#
# Finished Training. Time elapsed 1.054492
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.888074
#
# "Training Epoch Done": "Epoch": [38/100], "Loss": 0.4249
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.459965
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [38/100], "Loss": 0.4255
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [39/100], "Step": [0/188], "Loss": 0.4256
#
# Finished Training. Time elapsed 1.056492
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.888891
#
# "Training Epoch Done": "Epoch": [39/100], "Loss": 0.4278
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.461075
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [39/100], "Loss": 0.4280
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [40/100], "Step": [0/188], "Loss": 0.4223
#
# Finished Training. Time elapsed 1.089778
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.882623
#
# "Training Epoch Done": "Epoch": [40/100], "Loss": 0.4165
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.452989
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [40/100], "Loss": 0.4174
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [41/100], "Step": [0/188], "Loss": 0.4131
#
# Finished Training. Time elapsed 1.045885
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.898687
#
# "Training Epoch Done": "Epoch": [41/100], "Loss": 0.4115
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.456224
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [41/100], "Loss": 0.4124
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [42/100], "Step": [0/188], "Loss": 0.4176
#
# Finished Training. Time elapsed 1.050301
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.901398
#
# "Training Epoch Done": "Epoch": [42/100], "Loss": 0.3975
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.440103
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [42/100], "Loss": 0.3981
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [43/100], "Step": [0/188], "Loss": 0.4047
#
# Finished Training. Time elapsed 1.058225
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.891765
#
# "Training Epoch Done": "Epoch": [43/100], "Loss": 0.4225
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460962
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [43/100], "Loss": 0.4235
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.387749 ------
#
# "Epoch": [44/100], "Step": [0/188], "Loss": 0.4388
#
# Finished Training. Time elapsed 1.044694
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.882800
#
# "Training Epoch Done": "Epoch": [44/100], "Loss": 0.3826
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.461428
#
# "Best Loss": 0.38358699282010394
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [44/100], "Loss": 0.3836
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.383587 ------
#
# "Epoch": [45/100], "Step": [0/188], "Loss": 0.3805
#
# Finished Training. Time elapsed 1.052043
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.900487
#
# "Training Epoch Done": "Epoch": [45/100], "Loss": 0.3817
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.461626
#
# "Best Loss": 0.3828042130621653
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [45/100], "Loss": 0.3828
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.382804 ------
#
# "Epoch": [46/100], "Step": [0/188], "Loss": 0.3973
#
# Finished Training. Time elapsed 1.048985
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.902626
#
# "Training Epoch Done": "Epoch": [46/100], "Loss": 0.3967
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.463559
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [46/100], "Loss": 0.3973
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.382804 ------
#
# "Epoch": [47/100], "Step": [0/188], "Loss": 0.3914
#
# Finished Training. Time elapsed 1.050158
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.906337
#
# "Training Epoch Done": "Epoch": [47/100], "Loss": 0.3720
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.459872
#
# "Best Loss": 0.37252524826261735
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [47/100], "Loss": 0.3725
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.372525 ------
#
# "Epoch": [48/100], "Step": [0/188], "Loss": 0.3620
#
# Finished Training. Time elapsed 1.034005
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.884174
#
# "Training Epoch Done": "Epoch": [48/100], "Loss": 0.3753
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.450400
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [48/100], "Loss": 0.3756
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.372525 ------
#
# "Epoch": [49/100], "Step": [0/188], "Loss": 0.3662
#
# Finished Training. Time elapsed 1.055843
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.880443
#
# "Training Epoch Done": "Epoch": [49/100], "Loss": 0.4254
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.453073
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [49/100], "Loss": 0.4278
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.372525 ------
#
# "Epoch": [50/100], "Step": [0/188], "Loss": 0.4231
#
# Finished Training. Time elapsed 1.053385
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.941150
#
# "Training Epoch Done": "Epoch": [50/100], "Loss": 0.3070
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.471601
#
# "Best Loss": 0.30899275579149754
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [50/100], "Loss": 0.3090
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.308993 ------
#
# "Epoch": [51/100], "Step": [0/188], "Loss": 0.2931
#
# Finished Training. Time elapsed 1.114217
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.945826
#
# "Training Epoch Done": "Epoch": [51/100], "Loss": 0.2820
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.478633
#
# "Best Loss": 0.2838239371776581
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [51/100], "Loss": 0.2838
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.283824 ------
#
# "Epoch": [52/100], "Step": [0/188], "Loss": 0.2796
#
# Finished Training. Time elapsed 1.128027
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.888251
#
# "Training Epoch Done": "Epoch": [52/100], "Loss": 0.2797
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.453646
#
# "Best Loss": 0.2808394687516348
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [52/100], "Loss": 0.2808
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [53/100], "Step": [0/188], "Loss": 0.2824
#
# Finished Training. Time elapsed 1.040764
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.911018
#
# "Training Epoch Done": "Epoch": [53/100], "Loss": 0.2860
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.461283
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [53/100], "Loss": 0.2876
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [54/100], "Step": [0/188], "Loss": 0.2681
#
# Finished Training. Time elapsed 1.065887
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.888555
#
# "Training Epoch Done": "Epoch": [54/100], "Loss": 0.4219
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460197
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [54/100], "Loss": 0.4229
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [55/100], "Step": [0/188], "Loss": 0.4287
#
# Finished Training. Time elapsed 1.057380
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.891874
#
# "Training Epoch Done": "Epoch": [55/100], "Loss": 0.3539
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.467765
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [55/100], "Loss": 0.3552
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [56/100], "Step": [0/188], "Loss": 0.3652
#
# Finished Training. Time elapsed 1.058925
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.900036
#
# "Training Epoch Done": "Epoch": [56/100], "Loss": 0.4085
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.434835
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [56/100], "Loss": 0.4089
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [57/100], "Step": [0/188], "Loss": 0.4075
#
# Finished Training. Time elapsed 1.039982
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.880038
#
# "Training Epoch Done": "Epoch": [57/100], "Loss": 0.4414
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.457814
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [57/100], "Loss": 0.4431
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [58/100], "Step": [0/188], "Loss": 0.4377
#
# Finished Training. Time elapsed 1.034919
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.869715
#
# "Training Epoch Done": "Epoch": [58/100], "Loss": 0.4121
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.451400
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [58/100], "Loss": 0.4139
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [59/100], "Step": [0/188], "Loss": 0.4114
#
# Finished Training. Time elapsed 1.051160
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.899053
#
# "Training Epoch Done": "Epoch": [59/100], "Loss": 0.4357
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.459825
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [59/100], "Loss": 0.4356
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [60/100], "Step": [0/188], "Loss": 0.4366
#
# Finished Training. Time elapsed 1.043444
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.896582
#
# "Training Epoch Done": "Epoch": [60/100], "Loss": 0.4972
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.441702
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [60/100], "Loss": 0.4990
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [61/100], "Step": [0/188], "Loss": 0.4976
#
# Finished Training. Time elapsed 1.039559
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.888852
#
# "Training Epoch Done": "Epoch": [61/100], "Loss": 0.3852
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.445969
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [61/100], "Loss": 0.3892
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [62/100], "Step": [0/188], "Loss": 0.3882
#
# Finished Training. Time elapsed 1.053679
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.890221
#
# "Training Epoch Done": "Epoch": [62/100], "Loss": 0.4031
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.450085
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [62/100], "Loss": 0.4074
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.280839 ------
#
# "Epoch": [63/100], "Step": [0/188], "Loss": 0.4069
#
# Finished Training. Time elapsed 1.056053
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.893183
#
# "Training Epoch Done": "Epoch": [63/100], "Loss": 0.2365
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.454568
#
# "Best Loss": 0.23909084924629756
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [63/100], "Loss": 0.2391
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.239091 ------
#
# "Epoch": [64/100], "Step": [0/188], "Loss": 0.2299
#
# Finished Training. Time elapsed 1.056138
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.902058
#
# "Training Epoch Done": "Epoch": [64/100], "Loss": 0.2477
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.449173
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [64/100], "Loss": 0.2482
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.239091 ------
#
# "Epoch": [65/100], "Step": [0/188], "Loss": 0.2394
#
# Finished Training. Time elapsed 1.062700
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.894054
#
# "Training Epoch Done": "Epoch": [65/100], "Loss": 0.2201
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.448349
#
# "Best Loss": 0.2215476750381409
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [65/100], "Loss": 0.2215
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.221548 ------
#
# "Epoch": [66/100], "Step": [0/188], "Loss": 0.2128
#
# Finished Training. Time elapsed 1.045387
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.879670
#
# "Training Epoch Done": "Epoch": [66/100], "Loss": 0.2203
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.454525
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [66/100], "Loss": 0.2224
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.221548 ------
#
# "Epoch": [67/100], "Step": [0/188], "Loss": 0.2250
#
# Finished Training. Time elapsed 1.066628
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.887981
#
# "Training Epoch Done": "Epoch": [67/100], "Loss": 0.2907
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.445715
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [67/100], "Loss": 0.2931
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.221548 ------
#
# "Epoch": [68/100], "Step": [0/188], "Loss": 0.2758
#
# Finished Training. Time elapsed 1.048362
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.886303
#
# "Training Epoch Done": "Epoch": [68/100], "Loss": 0.2794
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.466821
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [68/100], "Loss": 0.2798
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.221548 ------
#
# "Epoch": [69/100], "Step": [0/188], "Loss": 0.2835
#
# Finished Training. Time elapsed 1.050865
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.893785
#
# "Training Epoch Done": "Epoch": [69/100], "Loss": 0.2015
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.459075
#
# "Best Loss": 0.2040865125637206
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [69/100], "Loss": 0.2041
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [70/100], "Step": [0/188], "Loss": 0.2119
#
# Finished Training. Time elapsed 1.066752
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.901113
#
# "Training Epoch Done": "Epoch": [70/100], "Loss": 0.2477
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.459354
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [70/100], "Loss": 0.2509
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [71/100], "Step": [0/188], "Loss": 0.2568
#
# Finished Training. Time elapsed 1.045144
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.882603
#
# "Training Epoch Done": "Epoch": [71/100], "Loss": 0.2549
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.464118
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [71/100], "Loss": 0.2566
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [72/100], "Step": [0/188], "Loss": 0.2850
#
# Finished Training. Time elapsed 1.044173
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.878574
#
# "Training Epoch Done": "Epoch": [72/100], "Loss": 0.3484
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.461761
#
# Validation Loss has gone up 3 times.
#
# "Validation Epoch Done": "Epoch": [72/100], "Loss": 0.3472
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [73/100], "Step": [0/188], "Loss": 0.3808
#
# Finished Training. Time elapsed 1.069545
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.877662
#
# "Training Epoch Done": "Epoch": [73/100], "Loss": 0.6930
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.446823
#
# Validation Loss has gone up 4 times.
#
# "Validation Epoch Done": "Epoch": [73/100], "Loss": 0.6931
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [74/100], "Step": [0/188], "Loss": 0.6941
#
# Finished Training. Time elapsed 1.057214
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.890430
#
# "Training Epoch Done": "Epoch": [74/100], "Loss": 0.6934
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.444114
#
# Validation Loss has gone up 5 times.
#
# "Validation Epoch Done": "Epoch": [74/100], "Loss": 0.6938
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [75/100], "Step": [0/188], "Loss": 0.6947
#
# Finished Training. Time elapsed 1.047613
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.898592
#
# "Training Epoch Done": "Epoch": [75/100], "Loss": 0.6935
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.459236
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [75/100], "Loss": 0.6931
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [76/100], "Step": [0/188], "Loss": 0.6966
#
# Finished Training. Time elapsed 1.047148
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.899247
#
# "Training Epoch Done": "Epoch": [76/100], "Loss": 0.6931
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.457319
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [76/100], "Loss": 0.6933
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [77/100], "Step": [0/188], "Loss": 0.6942
#
# Finished Training. Time elapsed 1.043736
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.893917
#
# "Training Epoch Done": "Epoch": [77/100], "Loss": 0.6938
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.451692
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [77/100], "Loss": 0.6943
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [78/100], "Step": [0/188], "Loss": 0.6921
#
# Finished Training. Time elapsed 1.056669
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.885393
#
# "Training Epoch Done": "Epoch": [78/100], "Loss": 0.4853
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.453284
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [78/100], "Loss": 0.4869
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [79/100], "Step": [0/188], "Loss": 0.4830
#
# Finished Training. Time elapsed 1.046022
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.897751
#
# "Training Epoch Done": "Epoch": [79/100], "Loss": 0.4816
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.452085
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [79/100], "Loss": 0.4820
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [80/100], "Step": [0/188], "Loss": 0.4831
#
# Finished Training. Time elapsed 1.053366
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.894946
#
# "Training Epoch Done": "Epoch": [80/100], "Loss": 0.4748
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.461259
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [80/100], "Loss": 0.4754
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [81/100], "Step": [0/188], "Loss": 0.4724
#
# Finished Training. Time elapsed 1.051543
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.890481
#
# "Training Epoch Done": "Epoch": [81/100], "Loss": 0.6930
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.444429
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [81/100], "Loss": 0.6929
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [82/100], "Step": [0/188], "Loss": 0.6923
#
# Finished Training. Time elapsed 1.056016
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.881176
#
# "Training Epoch Done": "Epoch": [82/100], "Loss": 0.6936
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.451298
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [82/100], "Loss": 0.6932
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [83/100], "Step": [0/188], "Loss": 0.6932
#
# Finished Training. Time elapsed 1.064321
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.883553
#
# "Training Epoch Done": "Epoch": [83/100], "Loss": 0.4692
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.451426
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [83/100], "Loss": 0.4699
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [84/100], "Step": [0/188], "Loss": 0.4811
#
# Finished Training. Time elapsed 1.044544
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.895085
#
# "Training Epoch Done": "Epoch": [84/100], "Loss": 0.4712
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.454969
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [84/100], "Loss": 0.4716
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [85/100], "Step": [0/188], "Loss": 0.4717
#
# Finished Training. Time elapsed 1.045790
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.891377
#
# "Training Epoch Done": "Epoch": [85/100], "Loss": 0.6051
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.455145
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [85/100], "Loss": 0.6033
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [86/100], "Step": [0/188], "Loss": 0.6100
#
# Finished Training. Time elapsed 1.055183
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.892393
#
# "Training Epoch Done": "Epoch": [86/100], "Loss": 0.4564
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.459048
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [86/100], "Loss": 0.4572
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [87/100], "Step": [0/188], "Loss": 0.4495
#
# Finished Training. Time elapsed 1.054168
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.876180
#
# "Training Epoch Done": "Epoch": [87/100], "Loss": 0.4594
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.452017
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [87/100], "Loss": 0.4598
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [88/100], "Step": [0/188], "Loss": 0.4742
#
# Finished Training. Time elapsed 1.057738
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.884731
#
# "Training Epoch Done": "Epoch": [88/100], "Loss": 0.6930
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460333
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [88/100], "Loss": 0.6930
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [89/100], "Step": [0/188], "Loss": 0.6923
#
# Finished Training. Time elapsed 1.071711
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.887179
#
# "Training Epoch Done": "Epoch": [89/100], "Loss": 0.4575
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460398
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [89/100], "Loss": 0.4590
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [90/100], "Step": [0/188], "Loss": 0.4548
#
# Finished Training. Time elapsed 1.055681
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.882737
#
# "Training Epoch Done": "Epoch": [90/100], "Loss": 0.4476
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.464067
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [90/100], "Loss": 0.4482
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [91/100], "Step": [0/188], "Loss": 0.4441
#
# Finished Training. Time elapsed 1.062770
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.898252
#
# "Training Epoch Done": "Epoch": [91/100], "Loss": 0.4422
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.451701
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [91/100], "Loss": 0.4436
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [92/100], "Step": [0/188], "Loss": 0.4442
#
# Finished Training. Time elapsed 1.045064
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.892687
#
# "Training Epoch Done": "Epoch": [92/100], "Loss": 0.4587
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.459179
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [92/100], "Loss": 0.4596
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [93/100], "Step": [0/188], "Loss": 0.4484
#
# Finished Training. Time elapsed 1.049424
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.884468
#
# "Training Epoch Done": "Epoch": [93/100], "Loss": 0.4868
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.452127
#
# Validation Loss has gone up 2 times.
#
# "Validation Epoch Done": "Epoch": [93/100], "Loss": 0.4887
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [94/100], "Step": [0/188], "Loss": 0.4680
#
# Finished Training. Time elapsed 1.062211
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.894622
#
# "Training Epoch Done": "Epoch": [94/100], "Loss": 0.6929
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.460061
#
# Validation Loss has gone up 3 times.
#
# "Validation Epoch Done": "Epoch": [94/100], "Loss": 0.6928
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [95/100], "Step": [0/188], "Loss": 0.6934
#
# Finished Training. Time elapsed 1.063629
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.896114
#
# "Training Epoch Done": "Epoch": [95/100], "Loss": 0.5153
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.462472
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [95/100], "Loss": 0.5175
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [96/100], "Step": [0/188], "Loss": 0.5333
#
# Finished Training. Time elapsed 1.061485
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.873488
#
# "Training Epoch Done": "Epoch": [96/100], "Loss": 0.6929
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.453952
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [96/100], "Loss": 0.6929
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [97/100], "Step": [0/188], "Loss": 0.6924
#
# Finished Training. Time elapsed 1.047028
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.887588
#
# "Training Epoch Done": "Epoch": [97/100], "Loss": 0.4437
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.447915
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [97/100], "Loss": 0.4444
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [98/100], "Step": [0/188], "Loss": 0.4398
#
# Finished Training. Time elapsed 1.083527
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.928088
#
# "Training Epoch Done": "Epoch": [98/100], "Loss": 0.4279
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.473731
#
# Validation Loss has gone up 0 times.
#
# "Validation Epoch Done": "Epoch": [98/100], "Loss": 0.4283
#
# ----- Starting Training Epoch lr=0.00100000 best_loss=0.204087 ------
#
# "Epoch": [99/100], "Step": [0/188], "Loss": 0.4156
#
# Finished Training. Time elapsed 1.116331
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.929454
#
# "Training Epoch Done": "Epoch": [99/100], "Loss": 0.4453
#
# ----- Starting Evaluation ------
#
# Finished evaluation. Time elapsed 0.479551
#
# Validation Loss has gone up 1 times.
#
# "Validation Epoch Done": "Epoch": [99/100], "Loss": 0.4461
